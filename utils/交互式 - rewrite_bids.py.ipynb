# %% [markdown]
# 已连接到 condamne (Python 3.9.0)

# %%
import mne
from mne_bids import BIDSPath, read_raw_bids,write_raw_bids
import os.path as op
import sys
sys.path.append(op.abspath('..'))
import utils.EEG as nod

missing_subs = ['15', '17','18', '19', '20', '23', '28']
databad_subs = ['16', '22', '25']
bad_subs = missing_subs + databad_subs

subs = [f'{sub:02d}' for sub in range(1, 31) if f'{sub:02d}' not in missing_subs]
sess = ['01', '02']
runs = [f'{run:02d}' for run in range(1, 9)]
ori_root = '/nfs/z1/userhome/zzl-zhangguohao/workingdir/NOD-MEEG_all/EEG/EEG-BIDS'
new_root = '/nfs/z1/userhome/zzl-zhangguohao/workingdir/NOD-MEEG_data/EEG-BIDS'
# Out:
# Now using CUDA device 0
# Enabling CUDA with 11.55 GB available memory

# %%
def bidsupdate(bids,po_raw):
    sub = bids.subject
    ses = bids.session
    run = bids.run
    task = bids.task
    raw = read_raw_bids(bids_path)
    init_raw = nod.preprocess(raw,sub,ses,run)
    init_raw.apply_montage()
    events,event_id = mne.events_from_annotations(raw)
    
    new_bids = BIDSPath(subject=sub, session=ses, run=run, task = task, 
                        root=new_root,datatype='eeg')
    write_raw_bids(init_raw, bids_path,events = events, 
                        event_id = event_id,montage=init_raw.get_montage())

# %%
bids = BIDSPath(subject='01', session='ImageNet01', task='ImageNet', run='01', root=ori_root)

# %%
raw = read_raw_bids(bids)

# %%
def bidsupdate(bids,po_raw,new_root):
    sub = bids.subject
    ses = bids.session
    run = bids.run
    task = bids.task
    raw = read_raw_bids(bids_path)
    init_raw = nod.preprocess(raw,sub,ses,run)
    init_raw.apply_montage()
    events,event_id = mne.events_from_annotations(raw)
    
    new_bids = BIDSPath(subject=sub, session=ses, run=run, task = task, 
                        root=new_root,datatype='eeg')
    write_raw_bids(init_raw, bids_path,events = events, 
                        event_id = event_id,montage=init_raw.get_montage())
    
    return raw

# %%
bids = BIDSPath(subject='01', session='ImageNet01', task='ImageNet', run='01', root=ori_root)
raw = bidsupdate(bids,raw,new_root)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /nfs/z1/userhome/zzl-zhangguohao/workingdir/NOD-MEEG_codes/EEG/rewrite_bids.py:3
#       1 #%%
#       2 bids = BIDSPath(subject='01', session='ImageNet01', task='ImageNet', run='01', root=ori_root)
# ----> 3 raw = bidsupdate(bids,raw,new_root)
#
# File /nfs/z1/userhome/zzl-zhangguohao/workingdir/NOD-MEEG_codes/EEG/rewrite_bids.py:7
#       5 run = bids.run
#       6 task = bids.task
# ----> 7 raw = read_raw_bids(bids_path)
#       8 init_raw = nod.preprocess(raw,sub,ses,run)
#       9 init_raw.apply_montage()
#
# NameError: name 'bids_path' is not defined

# %%
def bidsupdate(bids,po_raw,new_root):
    sub = bids.subject
    ses = bids.session
    run = bids.run
    task = bids.task
    raw = read_raw_bids(bids)
    init_raw = nod.preprocess(raw,sub,ses,run)
    init_raw.apply_montage()
    events,event_id = mne.events_from_annotations(raw)
    
    new_bids = BIDSPath(subject=sub, session=ses, run=run, task = task, 
                        root=new_root,datatype='eeg')
    write_raw_bids(init_raw, bids_path,events = events, 
                        event_id = event_id,montage=init_raw.get_montage())
    
    return raw

# %%
bids = BIDSPath(subject='01', session='ImageNet01', task='ImageNet', run='01', root=ori_root)
raw = bidsupdate(bids,raw,new_root)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /nfs/z1/userhome/zzl-zhangguohao/workingdir/NOD-MEEG_codes/EEG/rewrite_bids.py:3
#       1 #%%
#       2 bids = BIDSPath(subject='01', session='ImageNet01', task='ImageNet', run='01', root=ori_root)
# ----> 3 raw = bidsupdate(bids,raw,new_root)
#
# File /nfs/z1/userhome/zzl-zhangguohao/workingdir/NOD-MEEG_codes/EEG/rewrite_bids.py:8
#       6 task = bids.task
#       7 raw = read_raw_bids(bids)
# ----> 8 init_raw = nod.preprocess(raw,sub,ses,run)
#       9 init_raw.apply_montage()
#      10 events,event_id = mne.events_from_annotations(raw)
#
# AttributeError: module 'utils.EEG' has no attribute 'preprocess'

# %%
def bidsupdate(bids,po_raw,new_root):
    sub = bids.subject
    ses = bids.session
    run = bids.run
    task = bids.task
    raw = read_raw_bids(bids)
    init_raw = nod.EEGpreprocessing(raw,sub,ses,run)
    init_raw.apply_montage()
    events,event_id = mne.events_from_annotations(raw)
    
    new_bids = BIDSPath(subject=sub, session=ses, run=run, task = task, 
                        root=new_root,datatype='eeg')
    write_raw_bids(init_raw, bids_path,events = events, 
                        event_id = event_id,montage=init_raw.get_montage())
    
    return raw

# %%
bids = BIDSPath(subject='01', session='ImageNet01', task='ImageNet', run='01', root=ori_root)
raw = bidsupdate(bids,raw,new_root)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /nfs/z1/userhome/zzl-zhangguohao/workingdir/NOD-MEEG_codes/EEG/rewrite_bids.py:3
#       1 #%%
#       2 bids = BIDSPath(subject='01', session='ImageNet01', task='ImageNet', run='01', root=ori_root)
# ----> 3 raw = bidsupdate(bids,raw,new_root)
#
# File /nfs/z1/userhome/zzl-zhangguohao/workingdir/NOD-MEEG_codes/EEG/rewrite_bids.py:8
#       6 task = bids.task
#       7 raw = read_raw_bids(bids)
# ----> 8 init_raw = nod.EEGpreprocessing(raw,sub,ses,run)
#       9 init_raw.apply_montage()
#      10 events,event_id = mne.events_from_annotations(raw)
#
# AttributeError: module 'utils.EEG' has no attribute 'EEGpreprocessing'

# %%
def bidsupdate(bids,po_raw,new_root):
    sub = bids.subject
    ses = bids.session
    run = bids.run
    task = bids.task
    
    init_raw = nod.EEGPreprocessing(bids)
    init_raw.apply_montage()
    
    events,event_id = mne.events_from_annotations(raw)
    
    new_bids = BIDSPath(subject=sub, session=ses, run=run, task = task, 
                        root=new_root,datatype='eeg')
    write_raw_bids(init_raw, bids_path,events = events, 
                        event_id = event_id,montage=init_raw.get_montage())
    
    return raw

# %%
bids = BIDSPath(subject='01', session='ImageNet01', task='ImageNet', run='01', root=ori_root)
raw = bidsupdate(bids,raw,new_root)
# Out:
# 0724-11:37 - preprocessing - sub-01_ses-ImageNet01_task-ImageNet_run-01
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /nfs/z1/userhome/zzl-zhangguohao/workingdir/NOD-MEEG_codes/EEG/rewrite_bids.py:3
#       1 #%%
#       2 bids = BIDSPath(subject='01', session='ImageNet01', task='ImageNet', run='01', root=ori_root)
# ----> 3 raw = bidsupdate(bids,raw,new_root)
#
# File /nfs/z1/userhome/zzl-zhangguohao/workingdir/NOD-MEEG_codes/EEG/rewrite_bids.py:15
#      11 events,event_id = mne.events_from_annotations(raw)
#      13 new_bids = BIDSPath(subject=sub, session=ses, run=run, task = task,
#      14                     root=new_root,datatype='eeg')
# ---> 15 write_raw_bids(init_raw, bids_path,events = events,
#      16                     event_id = event_id,montage=init_raw.get_montage())
#      18 return raw
#
# NameError: name 'bids_path' is not defined

# %%
def bidsupdate(bids,po_raw,new_root):
    sub = bids.subject
    ses = bids.session
    run = bids.run
    task = bids.task
    
    init_raw = nod.EEGPreprocessing(bids)
    init_raw.apply_montage()
    
    events,event_id = mne.events_from_annotations(raw)
    
    new_bids = BIDSPath(subject=sub, session=ses, run=run, task = task, 
                        root=new_root,datatype='eeg')
    write_raw_bids(init_raw, new_bids,events = events, 
                        event_id = event_id,montage=init_raw.get_montage())
    
    return raw

# %%
bids = BIDSPath(subject='01', session='ImageNet01', task='ImageNet', run='01', root=ori_root)
raw = bidsupdate(bids,raw,new_root)
# Out:
# 0724-11:37 - preprocessing - sub-01_ses-ImageNet01_task-ImageNet_run-01
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /nfs/z1/userhome/zzl-zhangguohao/workingdir/NOD-MEEG_codes/EEG/rewrite_bids.py:3
#       1 #%%
#       2 bids = BIDSPath(subject='01', session='ImageNet01', task='ImageNet', run='01', root=ori_root)
# ----> 3 raw = bidsupdate(bids,raw,new_root)
#
# File /nfs/z1/userhome/zzl-zhangguohao/workingdir/NOD-MEEG_codes/EEG/rewrite_bids.py:16
#      11 events,event_id = mne.events_from_annotations(raw)
#      13 new_bids = BIDSPath(subject=sub, session=ses, run=run, task = task,
#      14                     root=new_root,datatype='eeg')
#      15 write_raw_bids(init_raw, new_bids,events = events,
# ---> 16                     event_id = event_id,montage=init_raw.get_montage())
#      18 return raw
#
# ...

# %%
def bidsupdate(bids,po_raw,new_root):
    sub = bids.subject
    ses = bids.session
    run = bids.run
    task = bids.task
    
    init_raw = nod.EEGPreprocessing(bids)
    init_raw.apply_montage()
    
    events,event_id = mne.events_from_annotations(raw)
    
    new_bids = BIDSPath(subject=sub, session=ses, run=run, task = task, 
                        root=new_root,datatype='eeg')
    write_raw_bids(init_raw, new_bids,events = events, 
                        event_id = event_id,montage=init_raw.raw.get_montage())
    
    return raw

# %%
bids = BIDSPath(subject='01', session='ImageNet01', task='ImageNet', run='01', root=ori_root)
raw = bidsupdate(bids,raw,new_root)
# Out:
# 0724-11:38 - preprocessing - sub-01_ses-ImageNet01_task-ImageNet_run-01
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /nfs/z1/userhome/zzl-zhangguohao/workingdir/NOD-MEEG_codes/EEG/rewrite_bids.py:3
#       1 #%%
#       2 bids = BIDSPath(subject='01', session='ImageNet01', task='ImageNet', run='01', root=ori_root)
# ----> 3 raw = bidsupdate(bids,raw,new_root)
#
# File /nfs/z1/userhome/zzl-zhangguohao/workingdir/NOD-MEEG_codes/EEG/rewrite_bids.py:15
#      11 events,event_id = mne.events_from_annotations(raw)
#      13 new_bids = BIDSPath(subject=sub, session=ses, run=run, task = task,
#      14                     root=new_root,datatype='eeg')
# ---> 15 write_raw_bids(init_raw, new_bids,events = events,
#      16                     event_id = event_id,montage=init_raw.raw.get_montage())
#      18 return raw
#
# ...

# %%
def bidsupdate(bids,po_raw,new_root):
    sub = bids.subject
    ses = bids.session
    run = bids.run
    task = bids.task
    
    init_raw = nod.EEGPreprocessing(bids)
    init_raw.apply_montage()
    
    events,event_id = mne.events_from_annotations(raw)
    
    new_bids = BIDSPath(subject=sub, session=ses, run=run, task = task, 
                        root=new_root,datatype='eeg')
    write_raw_bids(init_raw.raw, new_bids,events = events, 
                        event_id = event_id,montage=init_raw.raw.get_montage())
    
    return raw

# %%
bids = BIDSPath(subject='01', session='ImageNet01', task='ImageNet', run='01', root=ori_root)
raw = bidsupdate(bids,raw,new_root)
# Out:
# 0724-11:38 - preprocessing - sub-01_ses-ImageNet01_task-ImageNet_run-01
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /nfs/z1/userhome/zzl-zhangguohao/workingdir/NOD-MEEG_codes/EEG/rewrite_bids.py:3
#       1 #%%
#       2 bids = BIDSPath(subject='01', session='ImageNet01', task='ImageNet', run='01', root=ori_root)
# ----> 3 raw = bidsupdate(bids,raw,new_root)
#
# File /nfs/z1/userhome/zzl-zhangguohao/workingdir/NOD-MEEG_codes/EEG/rewrite_bids.py:15
#      11 events,event_id = mne.events_from_annotations(raw)
#      13 new_bids = BIDSPath(subject=sub, session=ses, run=run, task = task,
#      14                     root=new_root,datatype='eeg')
# ---> 15 write_raw_bids(init_raw.raw, new_bids,events = events,
#      16                     event_id = event_id,montage=init_raw.raw.get_montage())
#      18 return raw
#
# ...

# %%
def bidsupdate(bids,po_raw,new_root):
    sub = bids.subject
    ses = bids.session
    run = bids.run
    task = bids.task
    
    init_raw = nod.EEGPreprocessing(bids)
    init_raw.apply_montage()
    
    events,event_id = mne.events_from_annotations(raw)
    
    new_bids = BIDSPath(subject=sub, session=ses, run=run, task = task, 
                        root=new_root,datatype='eeg')
    write_raw_bids(init_raw.raw, new_bids,events = events, 
                        event_id = event_id,montage=init_raw.raw.get_montage(),allow_preload=True,format='eeglab')
    
    return raw

# %%
bids = BIDSPath(subject='01', session='ImageNet01', task='ImageNet', run='01', root=ori_root)
raw = bidsupdate(bids,raw,new_root)
# Out:
# 0724-11:38 - preprocessing - sub-01_ses-ImageNet01_task-ImageNet_run-01
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /nfs/z1/userhome/zzl-zhangguohao/workingdir/NOD-MEEG_codes/EEG/rewrite_bids.py:3
#       1 #%%
#       2 bids = BIDSPath(subject='01', session='ImageNet01', task='ImageNet', run='01', root=ori_root)
# ----> 3 raw = bidsupdate(bids,raw,new_root)
#
# File /nfs/z1/userhome/zzl-zhangguohao/workingdir/NOD-MEEG_codes/EEG/rewrite_bids.py:15
#      11 events,event_id = mne.events_from_annotations(raw)
#      13 new_bids = BIDSPath(subject=sub, session=ses, run=run, task = task,
#      14                     root=new_root,datatype='eeg')
# ---> 15 write_raw_bids(init_raw.raw, new_bids,events = events,
#      16                     event_id = event_id,montage=init_raw.raw.get_montage(),allow_preload=True,format='eeglab')
#      18 return raw
#
# ...

# %%
def bidsupdate(bids,po_raw,new_root):
    sub = bids.subject
    ses = bids.session
    run = bids.run
    task = bids.task
    
    init_raw = nod.EEGPreprocessing(bids)
    init_raw.apply_montage()
    
    events,event_id = mne.events_from_annotations(raw)
    
    new_bids = BIDSPath(subject=sub, session=ses, run=run, task = task, 
                        root=new_root,datatype='eeg')
    write_raw_bids(init_raw.raw, new_bids,events = events, 
                        event_id = event_id,montage=init_raw.raw.get_montage(),allow_preload=True,format='EEGLAB')
    
    return raw

# %%
bids = BIDSPath(subject='01', session='ImageNet01', task='ImageNet', run='01', root=ori_root)
raw = bidsupdate(bids,raw,new_root)
# Out:
# 0724-11:39 - preprocessing - sub-01_ses-ImageNet01_task-ImageNet_run-01
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /nfs/z1/userhome/zzl-zhangguohao/workingdir/NOD-MEEG_codes/EEG/rewrite_bids.py:3
#       1 #%%
#       2 bids = BIDSPath(subject='01', session='ImageNet01', task='ImageNet', run='01', root=ori_root)
# ----> 3 raw = bidsupdate(bids,raw,new_root)
#
# File /nfs/z1/userhome/zzl-zhangguohao/workingdir/NOD-MEEG_codes/EEG/rewrite_bids.py:15
#      11 events,event_id = mne.events_from_annotations(raw)
#      13 new_bids = BIDSPath(subject=sub, session=ses, run=run, task = task,
#      14                     root=new_root,datatype='eeg')
# ---> 15 write_raw_bids(init_raw.raw, new_bids,events = events,
#      16                     event_id = event_id,montage=init_raw.raw.get_montage(),allow_preload=True,format='EEGLAB')
#      18 return raw
#
# ...

# %%
def bidsupdate(bids,po_raw,new_root):
    sub = bids.subject
    ses = bids.session
    run = bids.run
    task = bids.task
    
    init_raw = nod.EEGPreprocessing(bids)
    init_raw.apply_montage()
    return raw
    # events,event_id = mne.events_from_annotations(raw)
    
    # new_bids = BIDSPath(subject=sub, session=ses, run=run, task = task, 
    #                     root=new_root,datatype='eeg')
    # write_raw_bids(init_raw.raw, new_bids,events = events, 
    #                     event_id = event_id,montage=init_raw.raw.get_montage(),allow_preload=True,format='EEGLAB')

# %%
bids = BIDSPath(subject='01', session='ImageNet01', task='ImageNet', run='01', root=ori_root)
raw = bidsupdate(bids,raw,new_root)
# Out:
# 0724-11:39 - preprocessing - sub-01_ses-ImageNet01_task-ImageNet_run-01

# %%
raw
# Out:
# <RawEEGLAB | sub-01_ses-ImageNet01_task-ImageNet_run-01_eeg.fdt, 66 x 95357 (190.7 s), ~94 kB, data not loaded>

# %%
raw.get_montage()
# Out:
# <DigMontage | 0 extras (headshape), 0 HPIs, 3 fiducials, 66 channels>

# %%
raw.get_montage.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 raw.get_montage.plot()
#
# AttributeError: 'function' object has no attribute 'plot'

# %%
raw.get_montage().plot()

# %%
raw.annotations
# Out:
# <Annotations | 1701 segments: 2 (125), 4 (1574), 8 (1), boundary (1)>

# %% [markdown]
# 已重启 condamne (Python 3.9.0)

# %%
import mne
from mne_bids import BIDSPath, read_raw_bids,write_raw_bids
import os.path as op
import sys
sys.path.append(op.abspath('..'))
import utils.EEG as nod

missing_subs = ['15', '17','18', '19', '20', '23', '28']
databad_subs = ['16', '22', '25']
bad_subs = missing_subs + databad_subs

subs = [f'{sub:02d}' for sub in range(1, 31) if f'{sub:02d}' not in missing_subs]
sess = ['01', '02']
runs = [f'{run:02d}' for run in range(1, 9)]
ori_root = '/nfs/z1/userhome/zzl-zhangguohao/workingdir/NOD-MEEG_all/EEG/EEG-BIDS'
new_root = '/nfs/z1/userhome/zzl-zhangguohao/workingdir/NOD-MEEG_data/EEG-BIDS'
# Out:
# Now using CUDA device 0
# Enabling CUDA with 14.27 GB available memory

# %%
def bidsupdate(bids,po_raw,new_root):
    sub = bids.subject
    ses = bids.session
    run = bids.run
    task = bids.task
    
    init_raw = nod.EEGPreprocessing(bids)
    init_raw.apply_montage()
    return raw
    # events,event_id = mne.events_from_annotations(raw)
    
    # new_bids = BIDSPath(subject=sub, session=ses, run=run, task = task, 
    #                     root=new_root,datatype='eeg')
    # write_raw_bids(init_raw.raw, new_bids,events = events, 
    #                     event_id = event_id,montage=init_raw.raw.get_montage(),allow_preload=True,format='EEGLAB')

# %%
bids = BIDSPath(subject='01', session='ImageNet01', task='ImageNet', run='01', root=ori_root)
raw = bidsupdate(bids,raw,new_root)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /nfs/z1/userhome/zzl-zhangguohao/workingdir/NOD-MEEG_codes/EEG/rewrite_bids.py:3
#       1 #%%
#       2 bids = BIDSPath(subject='01', session='ImageNet01', task='ImageNet', run='01', root=ori_root)
# ----> 3 raw = bidsupdate(bids,raw,new_root)
#
# NameError: name 'raw' is not defined

# %%
def bidsupdate(bids,new_root):
    sub = bids.subject
    ses = bids.session
    run = bids.run
    task = bids.task
    
    init_raw = nod.EEGPreprocessing(bids)
    init_raw.apply_montage()
    return raw
    # events,event_id = mne.events_from_annotations(raw)
    
    # new_bids = BIDSPath(subject=sub, session=ses, run=run, task = task, 
    #                     root=new_root,datatype='eeg')
    # write_raw_bids(init_raw.raw, new_bids,events = events, 
    #                     event_id = event_id,montage=init_raw.raw.get_montage(),allow_preload=True,format='EEGLAB')

# %%
bids = BIDSPath(subject='01', session='ImageNet01', task='ImageNet', run='01', root=ori_root)
raw = bidsupdate(bids,new_root)
# Out:
# 0724-11:44 - preprocessing - sub-01_ses-ImageNet01_task-ImageNet_run-01
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /nfs/z1/userhome/zzl-zhangguohao/workingdir/NOD-MEEG_codes/EEG/rewrite_bids.py:3
#       1 #%%
#       2 bids = BIDSPath(subject='01', session='ImageNet01', task='ImageNet', run='01', root=ori_root)
# ----> 3 raw = bidsupdate(bids,new_root)
#
# File /nfs/z1/userhome/zzl-zhangguohao/workingdir/NOD-MEEG_codes/EEG/rewrite_bids.py:10
#       8 init_raw = nod.EEGPreprocessing(bids)
#       9 init_raw.apply_montage()
# ---> 10 return raw
#
# NameError: name 'raw' is not defined

# %%
def bidsupdate(bids,new_root):
    sub = bids.subject
    ses = bids.session
    run = bids.run
    task = bids.task
    
    init_raw = nod.EEGPreprocessing(bids)
    init_raw.apply_montage()
    return init_raw
    # events,event_id = mne.events_from_annotations(raw)
    
    # new_bids = BIDSPath(subject=sub, session=ses, run=run, task = task, 
    #                     root=new_root,datatype='eeg')
    # write_raw_bids(init_raw.raw, new_bids,events = events, 
    #                     event_id = event_id,montage=init_raw.raw.get_montage(),allow_preload=True,format='EEGLAB')

# %%
bids = BIDSPath(subject='01', session='ImageNet01', task='ImageNet', run='01', root=ori_root)
raw = bidsupdate(bids,new_root)
# Out:
# 0724-11:44 - preprocessing - sub-01_ses-ImageNet01_task-ImageNet_run-01

# %%
raw.annotations
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 raw.annotations
#
# AttributeError: 'EEGPreprocessing' object has no attribute 'annotations'

# %%
raw.raw.annotations
# Out:
# <Annotations | 1701 segments: begin (1), end (1), resp (1574), stim_on (125)>

# %%
raw.raw.annotations[0]
# Out:
# OrderedDict([('onset', 0.0),
#              ('duration', 0.005),
#              ('description', 'begin'),
#              ('orig_time', None)])

# %%
raw.raw
# Out:
# <RawEEGLAB | sub-01_ses-ImageNet01_task-ImageNet_run-01_eeg.fdt, 64 x 95357 (190.7 s), ~46.6 MB, data loaded>

# %%
raw.raw.get_montage().plot()
